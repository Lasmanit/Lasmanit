# %%
"Vincent Van Guch" #I can also use ' to define string'
# Out:
# 'Vincent Van Guch'

# %%
"1 2 3 4" #string can also be a combination of special characters or special charecter as #$%^&
# Out:
# '1 2 3 4'

# %%
name="Vincent Van Guch" #I can bind or assign a string to another variable

# %%
name
# Out:
# 'Vincent Van Guch'

# %%
print(name[0]) #It is helpful to think of a string as an ordered sequence. Each element in the sequence can be accessed using an index represented by the array of numbers
# Out:
# V

# %%
# Because indexing starts at 0, it means the first index is on the index 0.

# %%
print(name[10])
# Out:
# n

# %%
#Negative index can help us to count the element from the end of the string.

# %%
print(name[-1])
# Out:
# h

# %%
len("Vincent Van Guch") #len is a short for length and it can can find the number of characters in a string
# Out:
# 16

# %%
name[0:5] #Slicing
# Out:
# 'Vince'

# %%
name[14:16]
# Out:
# 'ch'

# %%
name[::3] #Stride
# Out:
# 'VctaGh'

# %%
name[::2]
# Out:
# 'VnetVnGc'

# %%
name[0:4:3] #can also incorporate slicing with the stride. In this case, we select the first five elements and then use the stride:
# Out:
# 'Vc'

# %%
name[0:2:2]
# Out:
# 'V'

# %%
statement= name + "was talented"

# %%
statement #an concatenate or combine strings by using the addition symbols, and the result is a new string that is a combination of both
# Out:
# 'Vincent Van Guchwas talented'

# %%
4*name #can replicate string
# Out:
# 'Vincent Van GuchVincent Van GuchVincent Van GuchVincent Van Guch'

# %%
3*statement
# Out:
# 'Vincent Van Guchwas talentedVincent Van Guchwas talentedVincent Van Guchwas talented'

# %%
print("Vincent\n was missing an ear") #Back slashes represent the beginning of escape sequences. \n means a new line
# Out:
# Vincent
#  was missing an ear

# %%
print("Vincent \t is the best") #back slash "t" represents a tab
# Out:
# Vincent 	 is the best

# %%
print("Vincent \\ is the best") #If you want to place a back slash in your string, use a double back slash or a "r" in the begining of the sentence
# Out:
# Vincent \ is the best

# %%
#The method upper converts lower case characters to upper case characters

# %%
a="Vincent draw starry starry night"

# %%
a
# Out:
# 'Vincent draw starry starry night'

# %%
b= a.upper()

# %%
b
# Out:
# 'VINCENT DRAW STARRY STARRY NIGHT'

# %%
c="Rinat"

# %%
c
# Out:
# 'Rinat'

# %%
d=c.upper()

# %%
d
# Out:
# 'RINAT'

# %%
#The method replace replaces a segment of the string, i.e. a substring with a new string. We input the part of the string we would like to change. The second argument is what we would like to exchange the segment with, and the result is a new string with the segment changed

# %%
B=a.replace('Vincent', 'Bob Dylan')

# %%
B
# Out:
# 'Bob Dylan draw starry starry night'

# %%
#The method find finds a sub-string. The argument is the substring you would like to find, and the output is the first index of the sequence

# %%
name.find('Gu')
# Out:
# 12

# %%
name.find('ch')
# Out:
# 14
