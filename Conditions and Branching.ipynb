# %% [markdown]
# ## Condition Statements:

# %% [markdown]
# #### Comparison Operators

# %% [markdown]
# Comparison operations compare some value or operand and based on a condition, produce a Boolean. When comparing two values you can use these operators:
#
# * equal: ==
# * not equal: !=
# * greater than: >
# * less than: <
# * greater than or equal to: >=
# * less than or equal to: <=

# %%
# Condition Equal

a = 5
a == 6
# Out:
# False

# %%
# Greater than Sign

i = 6
i > 5
# Out:
# True

# %%
i = 2
i>5
# Out:
# False

# %%
i=5
i>5
# Out:
# False

# %%
# Inequality Sign

i = 2
i != 6
# Out:
# True

# %%
i=6
6!=6
# Out:
# False

# %%
# Use Equality sign to compare the strings

"ACDC" == "Michael Jackson"
# Out:
# False

# %%
"ACDC" != "Michael Jackson"
# Out:
# True

# %% [markdown]
# The inequality operation is also used to compare the letters/words/symbols according to the ASCII value of letters.

# %% [markdown]
# https://upload.wikimedia.org/wikipedia/commons/1/1b/ASCII-Table-wide.svg

# %%
'a'>'b'
# Out:
# False

# %%
'B'>'A'
# Out:
# True

# %%
'BA'>'AB'
# Out:
# True

# %% [markdown]
# When there are multiple letters, the first letter takes precedence in ordering.
# Note: Upper Case Letters have different ASCII code than Lower Case Letters, which means the comparison between the letters in Python is case-sensitive.

# %% [markdown]
# ### Branching

# %% [markdown]
# Branching allows us to run different statements for different inputs. It is helpful to think of an if statement as a locked room, if the statement is True we can enter the room and your program will run some predefined tasks, but if the statement is False the program will ignore the task.

# %%
#he syntax is as simple as  if condition statement :, which contains a word if, 
#any condition statement, 
#and a colon at the end

# %%
# If statement example

age = 19
#age = 18

#expression that can be true or false
if age > 18:
    
    #within an indent, we have the expression that is run if the condition is true
    print("you can enter" )

#The statements after the if statement will run regardless if the condition is true or false 
print("move on")
# Out:
# you can enter
# move on

# %%
age = 15
if age >18:
      print("you can enter")
print("move on")
# Out:
# move on

# %% [markdown]
# The else statement runs a block of code if none of the conditions are True before this else statement. The syntax of the else statement is similar as the syntax of the if statement, as else :

# %%
#ELSE statment example

age = 15
if age >18:
    print("you can enter")
else:
    print("sit in the corner")
print("move on")
# Out:
# sit in the corner
# move on

# %% [markdown]
# The elif statement, short for else if, allows us to check additional conditions if the condition statements before it are False. If the condition for the elif statement is True, the alternate expressions will be run

# %%
# Elif statment example

age=18
if age>18:
    print('you can enter')
elif age==18:
    print("enter to waiting list")
else:
    print("sit in the corner")
print("move on")
# Out:
# enter to waiting list
# move on

# %%
# Condition statement example

concert_year = 1988
#concert_year = 1970
if concert_year > 1980:
    print("I went to see that concert")
print("it wasnt nice")
# Out:
# I went to see that concert
# it wasnt nice

# %%
#concert_year = 1988
concert_year = 1970
if concert_year > 1980:
    print("I went to see that concert")
print("it wasnt nice")
# Out:
# it wasnt nice

# %%
#concert_year = 1988
concert_year = 1970
if concert_year > 1980:
    print("I went to see that concert")
else:
        print("I stayed at home")
print("it wasnt nice")
# Out:
# I stayed at home
# it wasnt nice

# %% [markdown]
# #### Logical operators

# %% [markdown]
# Sometimes you want to check more than one condition at once.You might want to check if one condition and another condition are both True. Logical operators allow you to combine or modify conditions.
#
# * and
# * or
# * not
#
# The *and* statement is only True when both conditions are true.
# The *or* statement is True if one condition, or both are True.
# The *not* statement outputs the opposite truth value.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/CondsTable.png" width="650" />

# %%
# Condition statement example - AND

concert_year = 1980

if concert_year > 1979 and concert_year < 1990:
    print ("The concert took place and Madonna came as a guest")
    
print("Madonna seemed to be tired")
print("But it still was great!")
# Out:
# The concert took place and Madonna came as a guest
# Madonna seemed to be tired
# But it still was great!

# %%
# Condition statement example - OR

concert_year = 1980
if concert_year < 1975 or concert_year > 1979:
    print ("The concert took place and Madonna came as a guest")
    
print("Madonna seemed to be tired")
print("But it still was great!")
# Out:
# The concert took place and Madonna came as a guest
# Madonna seemed to be tired
# But it still was great!

# %%
# Condition statement example - OR

concert_year = 1980
if concert_year < 1975 or concert_year > 1985:
    print ("The concert took place and Madonna came as a guest")
    
print("Madonna seemed to be tired")
print("But it still was great!")
# Out:
# Madonna seemed to be tired
# But it still was great!

# %%
# Condition statement example - NOT

concert_year = 1983

if not concert_year == '2000':
    print ("I never had the chance to see Madonna")
# Out:
# I never had the chance to see Madonna

# %%
album_year = 1983

if not (album_year == '1984'):
    print ("Album year is not 1984")
# Out:
# Album year is not 1984
