# %%
List= ["spagetti", "pizza", "cheese cake"]

# %%
List
# Out:
# ['spagetti', 'pizza', 'cheese cake']

# %%
List[2] #index starts with 0,1,2
# Out:
# 'cheese cake'

# %%
list=["Rinat", 12, 3.86, List]

# %%
list
# Out:
# ['Rinat', 12, 3.86, ['spagetti', 'pizza', 'cheese cake']]

# %%
list [2:5] #list slicing with value above the last index!
# Out:
# [3.86, ['spagetti', 'pizza', 'cheese cake', 'banana', 'avocado']]

# %%
lista=[1, 2, 3, 4]

# %%
lista
# Out:
# [1, 2, 3, 4]

# %%
lista [3:5]
# Out:
# [4]

# %%
List.extend(["banana", "avocado"]) #extend adds new elements

# %%
List
# Out:
# ['spagetti', 'pizza', 'cheese cake', 'banana', 'avocado']

# %%
List.append ([1,2,3]) #append adds one element only, no matter how many elemnts are inside

# %%
List
# Out:
# ['spagetti', 'pizza', 'cheese cake', 'banana', 'avocado', [1, 2, 3]]

# %%
#lists are mutabla = we can change them

# %%
del(List[5]) #del deletes an element

# %%
List
# Out:
# ['spagetti', 'pizza', 'cheese cake', 'banana', 'avocado']

# %%
#split = We can convert a string to a list using split. For example, the method split translates every group of characters separated by a space into an element in a list

# %%
'cheese cake'.split()
# Out:
# ['cheese', 'cake']

# %%
A= ["TV", 200, 0.5] #clone lists - examples:

# %%
A
# Out:
# ['TV', 200, 0.5]

# %%
B = A

# %%
B
# Out:
# ['TV', 200, 0.5]

# %%
print (A, B)
# Out:
# ['TV', 200, 0.5] ['TV', 200, 0.5]

# %%
A[0] = "radio"

# %%
A
# Out:
# ['radio', 200, 0.5]

# %%
print ('B[0]:', B[0])
A[0] = "radio"
print ('B[0]:', B[0])
# Out:
# B[0]: radio
# B[0]: radio

# %%
B = A[:]
B
# another way to clone lists. In this way B will not change if A will change
# Out:
# ['radio', 200, 0.5]

# %%
A = [1, "TRUE", 'b']
B = [100, "FALSE", 'd']
A+B
#concatenate lists = to unite
# Out:
# [1, 'TRUE', 'b', 100, 'FALSE', 'd']
