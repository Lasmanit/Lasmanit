# %%
#tuples ()

# %%
tuple1=("Roladin", 10)

# %%
tuple1 [1]
# Out:
# 10

# %%
tuple1[0]
# Out:
# 'Roladin'

# %%
print(tuple1[0])
print(tuple1[1])
# Out:
# Roladin
# 10

# %%
print(type(tuple1[0]))
print(type(tuple1[1]))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(tuple1[-1])
print(tuple1[-2])
# Out:
# 10
# Roladin

# %%
#We can concatenate or combine tuples by using the + sign:

# %%
tuple2=("banana", 3.8)

# %%
tuple1+ tuple2
# Out:
# ('Roladin', 10, 'banana', 3.8)

# %%
tuple3 = tuple1+tuple2

# %%
tuple3
# Out:
# ('Roladin', 10, 'banana', 3.8)

# %%
#We can slice tuples, obtaining new tuples with the corresponding elements (add plus one to the last element to get the element before)

# %%
tuple3[0:3]
# Out:
# ('Roladin', 10, 'banana')

# %%
len(tuple3)
# Out:
# 4

# %%
#sort - can orgenize the elements inside the tuple

# %%
scores= (10, 4, 8, 9, 1, 3, 3, 5, 6, 7, 6)

# %%
sorted(scores)
# Out:
# [1, 3, 3, 4, 5, 6, 6, 7, 8, 9, 10]

# %%
#nesting = A tuple can contain another tuple as well as other more complex data types.

# %%
Nestedlist= (3, "TRUE", ("need to shower", 0.88), ("banana", "cupacabana"))

# %%
print(Nestedlist[0])
print(Nestedlist[1])
print(Nestedlist[2])
print(Nestedlist[3])
#notice the ekement of each index
# Out:
# 3
# TRUE
# ('need to shower', 0.88)
# ('banana', 'cupacabana')

# %%
print(Nestedlist[2][0])
print(Nestedlist[2][1])
print(Nestedlist[3][0])
#We can access the nested tuples:
# Out:
# need to shower
# 0.88
# banana

# %%
print(Nestedlist[2][0][1])
#third tuple referes to letters
# Out:
# e

# %%
len(Nestedlist)
# Out:
# 4

# %%
Nestedlist.index("TRUE")
#to find an index inside a tuple
# Out:
# 1
